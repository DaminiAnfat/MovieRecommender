# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# Extracting features of 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df1 = pd.read_html(str(tables[0]))[0]

# %%
df1
# Out:
#      Opening  Opening.1                                   Title  \
# 0    JANUARY          3                              The Grudge
# 1    JANUARY         10                              Underwater
# 2    JANUARY         10                             Like a Boss
# 3    JANUARY         10                           Three Christs
# 4    JANUARY         10                       Inherit the Viper
# 5    JANUARY         10                              The Sonata
# 6    JANUARY         10      The Murder of Nicole Brown Simpson
# 7    JANUARY         17                       Bad Boys for Life
# 8    JANUARY         17                                Dolittle
# 9    JANUARY         17                       A Fall from Grace
# 10   JANUARY         24                           The Gentlemen
# 11   JANUARY         24                             The Turning
# 12   JANUARY         24                   The Last Full Measure
# 13   JANUARY         24                              John Henry
# 14   JANUARY         31                      The Rhythm Section
# 15   JANUARY         31                         Gretel & Hansel
# 16   JANUARY         31                           The Assistant
# 17  FEBRUARY          7                           Birds of Prey
# 18  FEBRUARY          7                               The Lodge
# 19  FEBRUARY          7       Timmy Failure: Mistakes Were Made
# 20  FEBRUARY          7                              Horse Girl
# 21  FEBRUARY         12  To All the Boys: P.S. I Still Love You
# 22  FEBRUARY         14                      Sonic the Hedgehog
# 23  FEBRUARY         14                          Fantasy Island
# 24  FEBRUARY         14                          The Photograph
# 25  FEBRUARY         14                                Downhill
# 26  FEBRUARY         14                        Spy Intervention
# 27  FEBRUARY         14               The Kindness of Strangers
# 28  FEBRUARY         21                    The Call of the Wild
# 29  FEBRUARY         21                The Last Thing He Wanted
# 30  FEBRUARY         21                      Brahms: The Boy II
# 31  FEBRUARY         21                                    Emma
# 32  FEBRUARY         21                         The Night Clerk
# 33  FEBRUARY         21           Impractical Jokers: The Movie
# 34  FEBRUARY         28                       The Invisible Man
# 35  FEBRUARY         28                   All the Bright Places
# 36  FEBRUARY         28                                   Wendy
# 37  FEBRUARY         28                             Guns Akimbo
# 38     MARCH          6                                  Onward
# 39     MARCH          6                            The Way Back
# 40     MARCH          6                    Spenser Confidential
# 41     MARCH          6                              The Banker
# 42     MARCH          6                 The Burnt Orange Heresy
# 43     MARCH          6                                 Swallow
# 44     MARCH          6                               First Cow
# 45     MARCH         13                               Bloodshot
# 46     MARCH         13                                The Hunt
# 47     MARCH         13                         I Still Believe
# 48     MARCH         13                              Lost Girls
# 49     MARCH         13                                Stargirl
# 50     MARCH         13                     The Roads Not Taken
# 51     MARCH         13           Never Rarely Sometimes Always
# 29                                               [29]
# 30                                               [30]
# 31                                                NaN
# 32                                               [31]
# 33                                               [32]
# 34                                               [33]
# 35                                               [34]
# 36                                               [35]
# 37                                               [36]
# 38                                               [37]
# 39                                               [38]
# 40                                               [39]
# 41                                               [40]
# 42                                               [41]
# 43                                               [42]
# 44                                               [43]
# 45                                               [44]
# 46                                               [45]
# 47                                               [46]
# 48                                               [47]
# 49                                               [48]
# 50                                               [49]
# 51                                               [50]
# 52                                               [51]
# 53                                               [52]
# 54                                               [53]
# 55                                               [54]
# 56                                               [55]

# %%
df1 = df1.rename(columns={'.mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.':'Ref.'})

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                  Title  \
# 0     JANUARY          3             The Grudge
# 1     JANUARY         10             Underwater
# 2     JANUARY         10            Like a Boss
# 3     JANUARY         10          Three Christs
# 4     JANUARY         10      Inherit the Viper
# ..        ...        ...                    ...
# 269  DECEMBER         25       We Can Be Heroes
# 270  DECEMBER         25      News of the World
# 271  DECEMBER         25  One Night in Miami...
# 272  DECEMBER         25  Promising Young Woman
# 273  DECEMBER         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                                   Paramount Pictures
# 3                                            IFC Films
# 4       Barry Films / Tycor International Film Company
# ..                                                 ...
# 269                     Netflix / Troublemaker Studios
# 270        Universal Pictures / Perfect World Pictures
# 271                                     Amazon Studios
# 272          Focus Features / FilmNation Entertainment
# 273                             Netflix / Bron Studios
#
#                                          Cast and crew   Ref.
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...    [2]
# 1    William Eubank (director); Brian Duffield, Ada...    [3]
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...    [4]
# 3    Jon Avnet (director/screenplay); Eric Nazarian...    NaN
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...    [5]
# ..                                                 ...    ...
# 269  Robert Rodriguez (director/screenplay); Priyan...  [241]
# 270  Paul Greengrass (director/screenplay); Luke Da...  [242]
# 271  Regina King (director); Kemp Powers (screenpla...  [243]
# 272  Emerald Fennell (director/screenplay); Carey M...  [244]
# 273  Kornél Mundruczó (director); Kata Wéber (scree...  [245]
#
# [274 rows x 6 columns]

# %%
df2 = pd.read_html(str(tables[1]))[0]

# %%
df2
# Out:
#    Opening  Opening.1                                            Title  \
# 0    APRIL          3                                  Coffee & Kareem
# 1    APRIL         10                                Trolls World Tour
# 2    APRIL         10                              Love Wedding Repeat
# 3    APRIL         10                                   The Main Event
# 4    APRIL         10                           We Summon the Darkness
# 5    APRIL         10                                 The Lost Husband
# 6    APRIL         10                                   Corona Zombies
# 7    APRIL         17                                           Sergio
# 8    APRIL         22                                  The Willoughbys
# 9    APRIL         24                                       Extraction
# 10   APRIL         24                               Braking for Whales
# 11   APRIL         25                                    Bad Education
# 12   APRIL         30                                   Dangerous Lies
# 269       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 270      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 271  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 272  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 273      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [274 rows x 2 columns]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in d:\datadam\anaconda3\envs\machinelearning\lib\site-packages (1.7.6)
# Requirement already satisfied: requests in d:\datadam\anaconda3\envs\machinelearning\lib\site-packages (from tmdbv3api) (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\datadam\anaconda3\envs\machinelearning\lib\site-packages (from requests->tmdbv3api) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\datadam\anaconda3\envs\machinelearning\lib\site-packages (from requests->tmdbv3api) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\datadam\anaconda3\envs\machinelearning\lib\site-packages (from requests->tmdbv3api) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\datadam\anaconda3\envs\machinelearning\lib\site-packages (from requests->tmdbv3api) (3.3)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '5492165c61b1a21c06eb3a3b578a6339'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# C:\Users\Damini\AppData\Local\Temp/ipykernel_30456/2588226551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 269       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 270      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 271  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 272  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 273      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres
# 0                   Horror Mystery Thriller
# 1    Action Horror Science Fiction Thriller
# 2                                    Comedy
# 3                                     Drama
# 4                      Crime Thriller Drama
# ..                                      ...
# 269            Action Fantasy Family Comedy
# 270                       Adventure Western
# 271                                   Drama
# 272                    Thriller Crime Drama
# 273                                   Drama
#
# [274 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\Damini\AppData\Local\Temp/ipykernel_30456/3848435694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\Damini\AppData\Local\Temp/ipykernel_30456/3646981363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 269       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 270      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 271  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 272  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 273      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres     director_name  \
# 0                   Horror Mystery Thriller     Nicolas Pesce
# 1    Action Horror Science Fiction Thriller    William Eubank
# 2                                    Comedy     Miguel Arteta
# 3                                     Drama         Jon Avnet
# 4                      Crime Thriller Drama    Anthony Jerjen
# ..                                      ...               ...
# 269            Action Fantasy Family Comedy  Robert Rodriguez
# 270                       Adventure Western   Paul Greengrass
# 271                                   Drama       Regina King
# 272                    Thriller Crime Drama   Emerald Fennell
# 273                                   Drama  Kornél Mundruczó
#
#               actor_1_name       actor_2_name     actor_3_name
# 0       Andrea Riseborough      Demián Bichir         John Cho
# 1          Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2          Tiffany Haddish         Rose Byrne      Salma Hayek
# 3             Richard Gere     Peter Dinklage   Walton Goggins
# 4            Josh Hartnett  Margarita Levieva   Chandler Riggs
# ..                     ...                ...              ...
# 269  Priyanka Chopra Jonas       Pedro Pascal    YaYa Gosselin
# 270              Tom Hanks      Helena Zengel              NaN
# 271      Kingsley Ben-Adir          Eli Goree      Aldis Hodge
# 272         Carey Mulligan         Bo Burnham      Alison Brie
# 273          Vanessa Kirby       Shia LaBeouf     Molly Parker
#
# [274 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 269  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 270   Paul Greengrass              Tom Hanks      Helena Zengel
# 271       Regina King      Kingsley Ben-Adir          Eli Goree
# 272   Emerald Fennell         Carey Mulligan         Bo Burnham
# 273  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                  genres  \
# 0           John Cho                 Horror Mystery Thriller
# 1    Jessica Henwick  Action Horror Science Fiction Thriller
# 2        Salma Hayek                                  Comedy
# 3     Walton Goggins                                   Drama
# 4     Chandler Riggs                    Crime Thriller Drama
# ..               ...                                     ...
# 269    YaYa Gosselin            Action Fantasy Family Comedy
# 270              NaN                       Adventure Western
# 271      Aldis Hodge                                   Drama
# 272      Alison Brie                    Thriller Crime Drama
# 273     Molly Parker                                   Drama
#
#                movie_title
# 0               The Grudge
# 1               Underwater
# 2              Like a Boss
# 3            Three Christs
# 4        Inherit the Viper
# ..                     ...
# 269       We Can Be Heroes
# 270      News of the World
# 271  One Night in Miami...
# 272  Promising Young Woman
# 273      Pieces of a Woman
#
# [274 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      4
# actor_3_name     27
# genres            1
# movie_title       0
# comb             28
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# C:\Users\Damini\AppData\Local\Temp/ipykernel_30456/2267385682.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 268       Pete Docter             Jamie Foxx           Tina Fey
# 269  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 271       Regina King      Kingsley Ben-Adir          Eli Goree
# 272   Emerald Fennell         Carey Mulligan         Bo Burnham
# 273  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5899  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 5900  Christian Bale Amy Adams Steve Carell Adam McK...
# 5901  Felicity Jones Armie Hammer Justin Theroux Mim...
# 5902  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 5903  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [5904 rows x 7 columns]

# %%
final_df = old_df.append(new_df20,ignore_index=True)

# %%
final_df
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         James Cameron            CCH Pounder  Joel David Moore
# 1        Gore Verbinski            Johnny Depp     Orlando Bloom
# 2            Sam Mendes        Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan              Tom Hardy    Christian Bale
# 4           Doug Walker            Doug Walker        Rob Walker
# ...                 ...                    ...               ...
# 6145        Pete Docter             Jamie Foxx          Tina Fey
# 6146   Robert Rodriguez  Priyanka Chopra Jonas      Pedro Pascal
# 6147        Regina King      Kingsley Ben-Adir         Eli Goree
# 6148    Emerald Fennell         Carey Mulligan        Bo Burnham
# 6149   Kornél Mundruczó          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 6145         Graham Norton  Animation Comedy Fantasy Family
# 6146         YaYa Gosselin     Action Fantasy Family Comedy
# 6147           Aldis Hodge                            Drama
# 6148           Alison Brie             Thriller Crime Drama
# 6149          Molly Parker                            Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6145                                               soul
# 6146                                   we can be heroes
# 6147                              one night in miami...
# 6148                              promising young woman
# 6149                                  pieces of a woman
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6145  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 6146  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 6147  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 6148  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 6149  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [6150 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)
