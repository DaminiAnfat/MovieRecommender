# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Extracting features of 2018 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"

# %%
df1 = pd.read_html(link, header=0)[2]

# %%
df1
# Out:
#     Opening  Opening.1                                Title  \
# 0   JANUARY          5              Insidious: The Last Key
# 1   JANUARY          5                     The Strange Ones
# 2   JANUARY          5                             Stratton
# 3   JANUARY         10                        Sweet Country
# 4   JANUARY         12                         The Commuter
# ..      ...        ...                                  ...
# 69    MARCH         29                     Ready Player One
# 70    MARCH         30               Tyler Perry's Acrimony
# 71    MARCH         30  God's Not Dead: A Light in Darkness
# 72    MARCH         30                               Gemini
# 73    MARCH         30                  The Last Movie Star
#
#                                    Production company  \
# 0   Universal Pictures / Blumhouse Productions / S...
# 1                              Vertical Entertainment
# 2                                   Momentum Pictures
# 3                                Samuel Goldwyn Films
# 4       Lionsgate / StudioCanal / The Picture Company
# ..                                                ...
# 69  Warner Bros. Pictures / Village Roadshow Pictu...
# 70                      Lionsgate / Tyler Perry Films
# 71                                          Pure Flix
# 72                                               Neon
# 73                                                A24
#
#                                         Cast and crew  \
# 0   Adam Robitel (director); Leigh Whannell (scree...
# 1   Lauren Wolkstein (director); Christopher Radcl...
# 2   Simon West (director); Duncan Falconer, Warren...
# 3   Warwick Thornton (director); David Tranter, St...
# 4   Jaume Collet-Serra (director); Byron Willinger...
# ..                                                ...
# 69  Steven Spielberg (director); Ernest Cline, Zak...
# 70  Tyler Perry (director/screenplay); Taraji P. H...
# 71  Michael Mason (director/screenplay); David A. ...
# 72  Aaron Katz (director/screenplay); Lola Kirke, ...
# 73  Adam Rifkin (director/screenplay); Burt Reynol...
#
#    .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.
# 0                                                 [2]
# 1                                                 [3]
# 2                                                 [4]
# 3                                                 [5]
# 4                                                 [6]
# ..                                                ...
# 69                                               [71]
# 70                                               [72]
# 71                                               [73]
# 72                                               [74]
# 73                                               [75]
#
# [74 rows x 6 columns]

# %%
df1 = df1.rename(columns={'.mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.':'Ref.'})

# %%
df1
# Out:
#     Opening  Opening.1                                Title  \
# 0   JANUARY          5              Insidious: The Last Key
# 1   JANUARY          5                     The Strange Ones
# 2   JANUARY          5                             Stratton
# 3   JANUARY         10                        Sweet Country
# 4   JANUARY         12                         The Commuter
# ..      ...        ...                                  ...
# 69    MARCH         29                     Ready Player One
# 70    MARCH         30               Tyler Perry's Acrimony
# 71    MARCH         30  God's Not Dead: A Light in Darkness
# 72    MARCH         30                               Gemini
# 73    MARCH         30                  The Last Movie Star
#
#                                    Production company  \
# 0   Universal Pictures / Blumhouse Productions / S...
# 1                              Vertical Entertainment
# 2                                   Momentum Pictures
# 3                                Samuel Goldwyn Films
# 4       Lionsgate / StudioCanal / The Picture Company
# ..                                                ...
# 69  Warner Bros. Pictures / Village Roadshow Pictu...
# 70                      Lionsgate / Tyler Perry Films
# 71                                          Pure Flix
# 72                                               Neon
# 73                                                A24
#
#                                         Cast and crew  Ref.
# 0   Adam Robitel (director); Leigh Whannell (scree...   [2]
# 1   Lauren Wolkstein (director); Christopher Radcl...   [3]
# 2   Simon West (director); Duncan Falconer, Warren...   [4]
# 3   Warwick Thornton (director); David Tranter, St...   [5]
# 4   Jaume Collet-Serra (director); Byron Willinger...   [6]
# ..                                                ...   ...
# 69  Steven Spielberg (director); Ernest Cline, Zak...  [71]
# 70  Tyler Perry (director/screenplay); Taraji P. H...  [72]
# 71  Michael Mason (director/screenplay); David A. ...  [73]
# 72  Aaron Katz (director/screenplay); Lola Kirke, ...  [74]
# 73  Adam Rifkin (director/screenplay); Burt Reynol...  [75]
#
# [74 rows x 6 columns]

# %%
df2 = pd.read_html(link, header=0)[3]

# %%
df2
# Out:
#    Opening  Opening.1                        Title  \
# 0    APRIL          6                A Quiet Place
# 1    APRIL          6                     Blockers
# 2    APRIL          6   You Were Never Really Here
# 3    APRIL          6               Chappaquiddick
# 4    APRIL          6                       Pandas
# ..     ...        ...                          ...
# 58    JUNE         28                The Domestics
# 59    JUNE         29  Sicario: Day of the Soldado
# 60    JUNE         29               Leave No Trace
# 61    JUNE         29                   Uncle Drew
# 62    JUNE         29            Woman Walks Ahead
#
#                                    Production company  \
# 0   Paramount Pictures / Platinum Dunes / Sunday N...
# 1   Universal Pictures / Good Universe / Point Gre...
# 2                                      Amazon Studios
# 3                               Entertainment Studios
# 4                        Warner Bros. Pictures / IMAX
# ..                                                ...
# 58                                     Orion Classics
# 59  Columbia Pictures / Black Label Media / Thunde...
# 60                                    Bleecker Street
# 61                               Summit Entertainment
# 62                                                A24
#
#                                         Cast and crew   Ref.
# 0   John Krasinski (director/screenplay); Scott Be...   [76]
# 1   Kay Cannon (director); Eben Russell, Jon Hurwi...   [77]
# 2   Lynne Ramsay (director/screenplay); Joaquin Ph...   [78]
# 3   John Curran (director); Taylor Allen, Andrew L...   [79]
# 4   Drew Fellman, David Douglas (directors); Drew ...   [80]
# ..                                                ...    ...
# 58  Mike P. Nelson (director/screenplay); Tyler Ho...  [130]
# 59  Stefano Sollima (director); Taylor Sheridan (s...  [131]
# 60  Debra Granik (director/screenplay); Anne Rosel...  [132]
# 61  Charles Stone III (director); Jay Longino (scr...  [133]
# 62  Susanna White (director); Steven Knight (scree...  [134]
#
# [63 rows x 6 columns]

# %%
df3 = pd.read_html(link, header=0)[4]

# %%
df3
# Out:
#       Opening  Opening.1                                  Title  \
# 0        JULY          4                        The First Purge
# 1        JULY          6                   Ant-Man and the Wasp
# 2        JULY          6                    Sorry to Bother You
# 3        JULY          6                                Whitney
# 4        JULY         13  Hotel Transylvania 3: Summer Vacation
# ..        ...        ...                                    ...
# 64  SEPTEMBER         25           My Hero Academia: Two Heroes
# 65  SEPTEMBER         28                              Smallfoot
# 66  SEPTEMBER         28                           Night School
# 67  SEPTEMBER         28                  The Old Man & the Gun
# 68  SEPTEMBER         28                              Hell Fest
#
#                                    Production company  \
# 0   Universal Pictures / Blumhouse Productions / P...
# 1                                      Marvel Studios
# 2                                  Annapurna Pictures
# 3                      Roadside Attractions / Miramax
# 4   Columbia Pictures / Sony Pictures Animation / MRC
# ..                                                ...
# 64                          Funimation / Toho / Bones
# 65     Warner Bros. Pictures / Warner Animation Group
# 66       Universal Pictures / Will Packer Productions
# 67                           Fox Searchlight Pictures
# 68                              Lionsgate / CBS Films
#
#                                         Cast and crew   Ref.
# 0   Gerard McMurray (director); James DeMonaco (sc...  [135]
# 1   Peyton Reed (director); Chris McKenna, Erik So...  [136]
# 2   Boots Riley (director/screenplay); Lakeith Sta...  [137]
# 3   Kevin MacDonald (director/screenplay); Whitney...  [138]
# 4   Genndy Tartakovsky (director/screenplay); Mich...  [139]
# ..                                                ...    ...
# 64  Kenji Nagasaki (director); Yōsuke Kuroda (scre...  [197]
# 65  Karey Kirkpatrick (director/screenplay); Clare...  [198]
# 66  Malcolm D. Lee (director); Kevin Hart, Harry R...  [199]
# 67  David Lowery (director/screenplay); Robert Red...  [200]
# 68  Gregory Plotkin (director); William Penick, Ch...  [201]
#
# [69 rows x 6 columns]

# %%
df4 = pd.read_html(link, header=0)[5]

# %%
df4
# Out:
#      Opening  Opening.1                            Title  \
# 0    OCTOBER          2                 Power of the Air
# 1    OCTOBER          5                            Venom
# 2    OCTOBER          5                   A Star Is Born
# 3    OCTOBER          5                  The Hate U Give
# 4    OCTOBER          5  The Great Buster: A Celebration
# ..       ...        ...                              ...
# 61  DECEMBER         25                  Holmes & Watson
# 62  DECEMBER         25                             Vice
# 63  DECEMBER         25              On the Basis of Sex
# 64  DECEMBER         25                        Destroyer
# 65  DECEMBER         28       Black Mirror: Bandersnatch
#
#                               Production company  \
# 0                            Five & Two Pictures
# 1       Columbia Pictures / Marvel Entertainment
# 2                          Warner Bros. Pictures
# 3           20th Century Fox / Fox 2000 Pictures
# 4                              Cohen Media Group
# ..                                           ...
# 61  Columbia Pictures / Gary Sanchez Productions
# 62     Annapurna Pictures / Plan B Entertainment
# 63                                Focus Features
# 64                            Annapurna Pictures
# 65                                       Netflix
#
#                                         Cast and crew   Ref.
# 0   Dave Christiano (director/screenplay); Nichola...  [202]
# 1   Ruben Fleischer (director); Jeff Pinkner, Scot...  [203]
# 2   Bradley Cooper (director/screenplay); Eric Rot...  [204]
# 3   George Tillman Jr. (director); Audrey Wells (s...  [205]
# 4                        Peter Bogdanovich (director)  [206]
# ..                                                ...    ...
# 61  Etan Cohen (director/screenplay); Will Ferrell...  [164]
# 62  Adam McKay (director/screenplay); Christian Ba...  [137]
# 63  Mimi Leder (director); Daniel Stiepleman (scre...  [228]
# 64  Karyn Kusama (director); Phil Hay, Matt Manfre...  [260]
# 65  David Slade (director); Charlie Brooker (scree...  [261]
#
# [66 rows x 6 columns]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 267  DECEMBER         25             Holmes & Watson
# 268  DECEMBER         25                        Vice
# 269  DECEMBER         25         On the Basis of Sex
# 270  DECEMBER         25                   Destroyer
# 271  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 267       Columbia Pictures / Gary Sanchez Productions
# 268          Annapurna Pictures / Plan B Entertainment
# 269                                     Focus Features
# 270                                 Annapurna Pictures
# 271                                            Netflix
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Lauren Wolkstein (director); Christopher Radcl...    [3]
# 2    Simon West (director); Duncan Falconer, Warren...    [4]
# 3    Warwick Thornton (director); David Tranter, St...    [5]
# 4    Jaume Collet-Serra (director); Byron Willinger...    [6]
# ..                                                 ...    ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...  [164]
# 268  Adam McKay (director/screenplay); Christian Ba...  [137]
# 269  Mimi Leder (director); Daniel Stiepleman (scre...  [228]
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...  [260]
# 271  David Slade (director); Charlie Brooker (scree...  [261]
#
# [272 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Opening               0
# Opening.1             0
# Title                 0
# Production company    0
# Cast and crew         0
# Ref.                  1
# dtype: int64

# %%
pip install tmdbv3api
# Out:
# Collecting tmdbv3apiNote: you may need to restart the kernel to use updated packages.
#   Downloading tmdbv3api-1.7.6-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: requests in d:\datadam\anaconda3\envs\machinelearning\lib\site-packages (from tmdbv3api) (2.26.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\datadam\anaconda3\envs\machinelearning\lib\site-packages (from requests->tmdbv3api) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\datadam\anaconda3\envs\machinelearning\lib\site-packages (from requests->tmdbv3api) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\datadam\anaconda3\envs\machinelearning\lib\site-packages (from requests->tmdbv3api) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in d:\datadam\anaconda3\envs\machinelearning\lib\site-packages (from requests->tmdbv3api) (2021.10.8)
# Installing collected packages: tmdbv3api
# Successfully installed tmdbv3api-1.7.6

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '5492165c61b1a21c06eb3a3b578a6339'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 267  DECEMBER         25             Holmes & Watson
# 268  DECEMBER         25                        Vice
# 269  DECEMBER         25         On the Basis of Sex
# 270  DECEMBER         25                   Destroyer
# 271  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 267       Columbia Pictures / Gary Sanchez Productions
# 268          Annapurna Pictures / Plan B Entertainment
# 269                                     Focus Features
# 270                                 Annapurna Pictures
# 271                                            Netflix
#
#                                          Cast and crew   Ref.  \
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Lauren Wolkstein (director); Christopher Radcl...    [3]
# 2    Simon West (director); Duncan Falconer, Warren...    [4]
# 3    Warwick Thornton (director); David Tranter, St...    [5]
# 4    Jaume Collet-Serra (director); Byron Willinger...    [6]
# ..                                                 ...    ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...  [164]
# 268  Adam McKay (director/screenplay); Christian Ba...  [137]
# 269  Mimi Leder (director); Daniel Stiepleman (scre...  [228]
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...  [260]
# 271  David Slade (director); Charlie Brooker (scree...  [261]
#
#                                               genres
# 0                            Horror Mystery Thriller
# 1                                     Thriller Drama
# 2                                    Action Thriller
# 3                              Drama History Western
# 4                            Action Thriller Mystery
# ..                                               ...
# 267                   Mystery Adventure Comedy Crime
# 268        Thriller Science Fiction Action Adventure
# 269                                    Drama History
# 270                      Thriller Crime Drama Action
# 271  Science Fiction Mystery Drama Thriller TV Movie
#
# [272 rows x 7 columns]

# %%
df_2018 = df[['Title','Cast and crew','genres']]

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271  David Slade (director); Charlie Brooker (scree...
#
#                                               genres
# 0                            Horror Mystery Thriller
# 1                                     Thriller Drama
# 2                                    Action Thriller
# 3                              Drama History Western
# 4                            Action Thriller Mystery
# ..                                               ...
# 267                   Mystery Adventure Comedy Crime
# 268        Thriller Science Fiction Action Adventure
# 269                                    Drama History
# 270                      Thriller Crime Drama Action
# 271  Science Fiction Mystery Drama Thriller TV Movie
#
# [272 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\Users\Damini\AppData\Local\Temp/ipykernel_1240/930721595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\Damini\AppData\Local\Temp/ipykernel_1240/2274966287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\Damini\AppData\Local\Temp/ipykernel_1240/3672495884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271  David Slade (director); Charlie Brooker (scree...
#
#                                               genres       director_name  \
# 0                            Horror Mystery Thriller        Adam Robitel
# 1                                     Thriller Drama    Lauren Wolkstein
# 2                                    Action Thriller          Simon West
# 3                              Drama History Western    Warwick Thornton
# 4                            Action Thriller Mystery  Jaume Collet-Serra
# ..                                               ...                 ...
# 267                   Mystery Adventure Comedy Crime          Etan Cohen
# 268        Thriller Science Fiction Action Adventure          Adam McKay
# 269                                    Drama History          Mimi Leder
# 270                      Thriller Crime Drama Action        Karyn Kusama
# 271  Science Fiction Mystery Drama Thriller TV Movie         David Slade
#
#         actor_1_name            actor_2_name    actor_3_name
# 0          Lin Shaye           Angus Sampson  Leigh Whannell
# 1      Alex Pettyfer  James Freedson-Jackson   Emily Althaus
# 2     Dominic Cooper          Austin Stowell      Gemma Chan
# 3        Bryan Brown               Sam Neill             NaN
# 4        Liam Neeson            Vera Farmiga  Patrick Wilson
# ..               ...                     ...             ...
# 267     Will Ferrell          John C. Reilly    Rebecca Hall
# 268   Christian Bale               Amy Adams    Steve Carell
# 269   Felicity Jones            Armie Hammer  Justin Theroux
# 270    Nicole Kidman          Sebastian Stan    Toby Kebbell
# 271  Fionn Whitehead            Will Poulter   Asim Chaudhry
#
# [272 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 267          Etan Cohen     Will Ferrell          John C. Reilly
# 268          Adam McKay   Christian Bale               Amy Adams
# 269          Mimi Leder   Felicity Jones            Armie Hammer
# 270        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 271         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# 1     Emily Althaus                                   Thriller Drama
# 2        Gemma Chan                                  Action Thriller
# 3               NaN                            Drama History Western
# 4    Patrick Wilson                          Action Thriller Mystery
# ..              ...                                              ...
# 267    Rebecca Hall                   Mystery Adventure Comedy Crime
# 268    Steve Carell        Thriller Science Fiction Action Adventure
# 269  Justin Theroux                                    Drama History
# 270    Toby Kebbell                      Thriller Crime Drama Action
# 271   Asim Chaudhry  Science Fiction Mystery Drama Thriller TV Movie
#
#                     movie_title
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
# [272 rows x 6 columns]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 267          Etan Cohen     Will Ferrell          John C. Reilly
# 268          Adam McKay   Christian Bale               Amy Adams
# 269          Mimi Leder   Felicity Jones            Armie Hammer
# 270        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 271         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# 1     Emily Althaus                                   Thriller Drama
# 2        Gemma Chan                                  Action Thriller
# 3           unknown                            Drama History Western
# 4    Patrick Wilson                          Action Thriller Mystery
# ..              ...                                              ...
# 267    Rebecca Hall                   Mystery Adventure Comedy Crime
# 268    Steve Carell        Thriller Science Fiction Action Adventure
# 269  Justin Theroux                                    Drama History
# 270    Toby Kebbell                      Thriller Crime Drama Action
# 271   Asim Chaudhry  Science Fiction Mystery Drama Thriller TV Movie
#
#                     movie_title  \
# 0       insidious: the last key
# 1              the strange ones
# 2                      stratton
# 3                 sweet country
# 4                  the commuter
# ..                          ...
# 267             holmes & watson
# 268                        vice
# 269         on the basis of sex
# 270                   destroyer
# 271  black mirror: bandersnatch
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 267  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 268  Christian Bale Amy Adams Steve Carell Adam McK...
# 269  Felicity Jones Armie Hammer Justin Theroux Mim...
# 270  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 271  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [272 rows x 7 columns]

# %%
new_df18.isnull().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           2
# movie_title      0
# comb             2
# dtype: int64

# %% [markdown]
# Extracting features of 2019 movies from Wikipedia

# %%
ink = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 267  DECEMBER         25             Holmes & Watson
# 268  DECEMBER         25                        Vice
# 269  DECEMBER         25         On the Basis of Sex
# 270  DECEMBER         25                   Destroyer
# 271  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 267       Columbia Pictures / Gary Sanchez Productions
# 268          Annapurna Pictures / Plan B Entertainment
# 269                                     Focus Features
# 270                                 Annapurna Pictures
# 271                                            Netflix
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271  David Slade (director); Charlie Brooker (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 267  [164]
# 268  [137]
# 269  [228]
# 270  [260]
# 271  [261]
#
# [272 rows x 7 columns]

# %%
df1 = pd.read_html(link, header=0)[2]

# %%
df1
# Out:
#     Opening  Opening.1                                Title  \
# 0   JANUARY          5              Insidious: The Last Key
# 1   JANUARY          5                     The Strange Ones
# 2   JANUARY          5                             Stratton
# 3   JANUARY         10                        Sweet Country
# 4   JANUARY         12                         The Commuter
# ..      ...        ...                                  ...
# 69    MARCH         29                     Ready Player One
# 70    MARCH         30               Tyler Perry's Acrimony
# 71    MARCH         30  God's Not Dead: A Light in Darkness
# 72    MARCH         30                               Gemini
# 73    MARCH         30                  The Last Movie Star
#
#                                    Production company  \
# 0   Universal Pictures / Blumhouse Productions / S...
# 1                              Vertical Entertainment
# 2                                   Momentum Pictures
# 3                                Samuel Goldwyn Films
# 4       Lionsgate / StudioCanal / The Picture Company
# ..                                                ...
# 69  Warner Bros. Pictures / Village Roadshow Pictu...
# 70                      Lionsgate / Tyler Perry Films
# 71                                          Pure Flix
# 72                                               Neon
# 73                                                A24
#
#                                         Cast and crew  \
# 0   Adam Robitel (director); Leigh Whannell (scree...
# 1   Lauren Wolkstein (director); Christopher Radcl...
# 2   Simon West (director); Duncan Falconer, Warren...
# 3   Warwick Thornton (director); David Tranter, St...
# 4   Jaume Collet-Serra (director); Byron Willinger...
# ..                                                ...
# 69  Steven Spielberg (director); Ernest Cline, Zak...
# 70  Tyler Perry (director/screenplay); Taraji P. H...
# 71  Michael Mason (director/screenplay); David A. ...
# 72  Aaron Katz (director/screenplay); Lola Kirke, ...
# 73  Adam Rifkin (director/screenplay); Burt Reynol...
#
#    .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.
# 0                                                 [2]
# 1                                                 [3]
# 2                                                 [4]
# 3                                                 [5]
# 4                                                 [6]
# ..                                                ...
# 69                                               [71]
# 70                                               [72]
# 71                                               [73]
# 72                                               [74]
# 73                                               [75]
#
# [74 rows x 6 columns]

# %%
df1 = df1.rename(columns={'.mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.':'Ref.'})

# %%
df1
# Out:
#     Opening  Opening.1                                Title  \
# 0   JANUARY          5              Insidious: The Last Key
# 1   JANUARY          5                     The Strange Ones
# 2   JANUARY          5                             Stratton
# 3   JANUARY         10                        Sweet Country
# 4   JANUARY         12                         The Commuter
# ..      ...        ...                                  ...
# 69    MARCH         29                     Ready Player One
# 70    MARCH         30               Tyler Perry's Acrimony
# 71    MARCH         30  God's Not Dead: A Light in Darkness
# 72    MARCH         30                               Gemini
# 73    MARCH         30                  The Last Movie Star
#
#                                    Production company  \
# 0   Universal Pictures / Blumhouse Productions / S...
# 1                              Vertical Entertainment
# 2                                   Momentum Pictures
# 3                                Samuel Goldwyn Films
# 4       Lionsgate / StudioCanal / The Picture Company
# ..                                                ...
# 69  Warner Bros. Pictures / Village Roadshow Pictu...
# 70                      Lionsgate / Tyler Perry Films
# 71                                          Pure Flix
# 72                                               Neon
# 73                                                A24
#
#                                         Cast and crew  Ref.
# 0   Adam Robitel (director); Leigh Whannell (scree...   [2]
# 1   Lauren Wolkstein (director); Christopher Radcl...   [3]
# 2   Simon West (director); Duncan Falconer, Warren...   [4]
# 3   Warwick Thornton (director); David Tranter, St...   [5]
# 4   Jaume Collet-Serra (director); Byron Willinger...   [6]
# ..                                                ...   ...
# 69  Steven Spielberg (director); Ernest Cline, Zak...  [71]
# 70  Tyler Perry (director/screenplay); Taraji P. H...  [72]
# 71  Michael Mason (director/screenplay); David A. ...  [73]
# 72  Aaron Katz (director/screenplay); Lola Kirke, ...  [74]
# 73  Adam Rifkin (director/screenplay); Burt Reynol...  [75]
#
# [74 rows x 6 columns]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 267  DECEMBER         25             Holmes & Watson
# 268  DECEMBER         25                        Vice
# 269  DECEMBER         25         On the Basis of Sex
# 270  DECEMBER         25                   Destroyer
# 271  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 267       Columbia Pictures / Gary Sanchez Productions
# 268          Annapurna Pictures / Plan B Entertainment
# 269                                     Focus Features
# 270                                 Annapurna Pictures
# 271                                            Netflix
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Lauren Wolkstein (director); Christopher Radcl...    [3]
# 2    Simon West (director); Duncan Falconer, Warren...    [4]
# 3    Warwick Thornton (director); David Tranter, St...    [5]
# 4    Jaume Collet-Serra (director); Byron Willinger...    [6]
# ..                                                 ...    ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...  [164]
# 268  Adam McKay (director/screenplay); Christian Ba...  [137]
# 269  Mimi Leder (director); Daniel Stiepleman (scre...  [228]
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...  [260]
# 271  David Slade (director); Charlie Brooker (scree...  [261]
#
# [272 rows x 6 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
df_2019
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 267             Holmes & Watson
# 268                        Vice
# 269         On the Basis of Sex
# 270                   Destroyer
# 271  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 267  Etan Cohen (director/screenplay); Will Ferrell...
# 268  Adam McKay (director/screenplay); Christian Ba...
# 269  Mimi Leder (director); Daniel Stiepleman (scre...
# 270  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 271  David Slade (director); Charlie Brooker (scree...
#
#                                               genres
# 0                            Horror Mystery Thriller
# 1                                     Thriller Drama
# 2                                    Action Thriller
# 3                              Drama History Western
# 4                            Action Thriller Mystery
# ..                                               ...
# 267                   Mystery Adventure Comedy Crime
# 268        Thriller Science Fiction Action Adventure
# 269                                    Drama History
# 270                      Thriller Crime Drama Action
# 271  Science Fiction Mystery Drama Thriller TV Movie
#
# [272 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\Damini\AppData\Local\Temp/ipykernel_1240/203239715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\Damini\AppData\Local\Temp/ipykernel_1240/1562076556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\Damini\AppData\Local\Temp/ipykernel_1240/3736213850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 267          Etan Cohen     Will Ferrell          John C. Reilly
# 268          Adam McKay   Christian Bale               Amy Adams
# 269          Mimi Leder   Felicity Jones            Armie Hammer
# 270        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 271         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# 1     Emily Althaus                                   Thriller Drama
# 2        Gemma Chan                                  Action Thriller
# 3           unknown                            Drama History Western
# 4    Patrick Wilson                          Action Thriller Mystery
# ..              ...                                              ...
# 267    Rebecca Hall                   Mystery Adventure Comedy Crime
# 268    Steve Carell        Thriller Science Fiction Action Adventure
# 269  Justin Theroux                                    Drama History
# 270    Toby Kebbell                      Thriller Crime Drama Action
# 271   Asim Chaudhry  Science Fiction Mystery Drama Thriller TV Movie
#
#                     movie_title  \
# 0       insidious: the last key
# 1              the strange ones
# 2                      stratton
# 3                 sweet country
# 4                  the commuter
# ..                          ...
# 267             holmes & watson
# 268                        vice
# 269         on the basis of sex
# 270                   destroyer
# 271  black mirror: bandersnatch
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 267  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 268  Christian Bale Amy Adams Steve Carell Adam McK...
# 269  Felicity Jones Armie Hammer Justin Theroux Mim...
# 270  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 271  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [272 rows x 7 columns]

# %%
my_df = new_df18.append(new_df19,ignore_index=True)

# %%
my_df
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 539          Etan Cohen     Will Ferrell          John C. Reilly
# 540          Adam McKay   Christian Bale               Amy Adams
# 541          Mimi Leder   Felicity Jones            Armie Hammer
# 542        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 543         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# 1     Emily Althaus                                   Thriller Drama
# 2        Gemma Chan                                  Action Thriller
# 3           unknown                            Drama History Western
# 4    Patrick Wilson                          Action Thriller Mystery
# ..              ...                                              ...
# 539    Rebecca Hall                   Mystery Adventure Comedy Crime
# 540    Steve Carell        Thriller Science Fiction Action Adventure
# 541  Justin Theroux                                    Drama History
# 542    Toby Kebbell                      Thriller Crime Drama Action
# 543   Asim Chaudhry  Science Fiction Mystery Drama Thriller TV Movie
#
#                     movie_title  \
# 0       insidious: the last key
# 1              the strange ones
# 2                      stratton
# 3                 sweet country
# 4                  the commuter
# ..                          ...
# 539             holmes & watson
# 540                        vice
# 541         on the basis of sex
# 542                   destroyer
# 543  black mirror: bandersnatch
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 539  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 540  Christian Bale Amy Adams Steve Carell Adam McK...
# 541  Felicity Jones Armie Hammer Justin Theroux Mim...
# 542  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 543  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [544 rows x 7 columns]

# %%
old_df = pd.read_csv('new_data.csv')

# %%
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5359       Keith Stanfield                   Romance Comedy
# 5360     Jean Louisa Kelly                          Romance
# 5361        Tiitus Rantala                   Romance Comedy
# 5362           Gina Holden       Crime Comedy Action Family
# 5363        Akshaye Khanna             Crime Drama Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5359                       the incredible jessica james
# 5360                                  can't buy my love
# 5361                   thick lashes of lauri mäntyvaara
# 5362                        cop and a half: new recruit
# 5363                                                mom
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5359  Jessica Williams Chris O'Dowd Keith Stanfield ...
# 5360  Adelaide Kane Benjamin Hollingsworth Jean Loui...
# 5361  Inka Haapamäki Rosa Honkonen Tiitus Rantala Ha...
# 5362  Lou Diamond Phillips Wallace Shawn Gina Holden...
# 5363  Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi U...
#
# [5364 rows x 7 columns]

# %%
final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 5903         Etan Cohen     Will Ferrell    John C. Reilly
# 5904         Adam McKay   Christian Bale         Amy Adams
# 5905         Mimi Leder   Felicity Jones      Armie Hammer
# 5906       Karyn Kusama    Nicole Kidman    Sebastian Stan
# 5907        David Slade  Fionn Whitehead      Will Poulter
#
#               actor_3_name                                           genres  \
# 0                Wes Studi                  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                         Action Adventure Fantasy
# 2         Stephanie Sigman                        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                                  Action Thriller
# 4                  unknown                                      Documentary
# ...                    ...                                              ...
# 5903          Rebecca Hall                   Mystery Adventure Comedy Crime
# 5904          Steve Carell        Thriller Science Fiction Action Adventure
# 5905        Justin Theroux                                    Drama History
# 5906          Toby Kebbell                      Thriller Crime Drama Action
# 5907         Asim Chaudhry  Science Fiction Mystery Drama Thriller TV Movie
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5903                                    holmes & watson
# 5904                                               vice
# 5905                                on the basis of sex
# 5906                                          destroyer
# 5907                         black mirror: bandersnatch
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5903  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 5904  Christian Bale Amy Adams Steve Carell Adam McK...
# 5905  Felicity Jones Armie Hammer Justin Theroux Mim...
# 5906  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 5907  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [5908 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           4
# movie_title      0
# comb             4
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 5903         Etan Cohen     Will Ferrell    John C. Reilly
# 5904         Adam McKay   Christian Bale         Amy Adams
# 5905         Mimi Leder   Felicity Jones      Armie Hammer
# 5906       Karyn Kusama    Nicole Kidman    Sebastian Stan
# 5907        David Slade  Fionn Whitehead      Will Poulter
#
#               actor_3_name                                           genres  \
# 0                Wes Studi                  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                         Action Adventure Fantasy
# 2         Stephanie Sigman                        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                                  Action Thriller
# 4                  unknown                                      Documentary
# ...                    ...                                              ...
# 5903          Rebecca Hall                   Mystery Adventure Comedy Crime
# 5904          Steve Carell        Thriller Science Fiction Action Adventure
# 5905        Justin Theroux                                    Drama History
# 5906          Toby Kebbell                      Thriller Crime Drama Action
# 5907         Asim Chaudhry  Science Fiction Mystery Drama Thriller TV Movie
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5903                                    holmes & watson
# 5904                                               vice
# 5905                                on the basis of sex
# 5906                                          destroyer
# 5907                         black mirror: bandersnatch
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5903  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 5904  Christian Bale Amy Adams Steve Carell Adam McK...
# 5905  Felicity Jones Armie Hammer Justin Theroux Mim...
# 5906  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 5907  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [5904 rows x 7 columns]

# %%
final_df.to_csv('final_data.csv',index=False)
